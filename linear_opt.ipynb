# %%
import os
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
columns = ['Bypass Fraction', 'NG Steam Ratio', 'Steam Flow',
           'Reformer Duty','AR', 'C2H6', 'C3H8', 'C4H10',
           'CH4', 'CO', 'CO2', 'H2', 'H2O', 'N2']
df = pd.read_csv(r'C:\Users\jwiggins\Documents\Python_virtual_env\Supply Chain Simulation\supply_chain_simulation\supply_chain_simulation\nn_optimization\reformer.csv', usecols=columns)
print(df)
# Out:
#       Bypass Fraction  NG Steam Ratio  Steam Flow  Reformer Duty        AR  \
# 0                 0.8        0.800000    0.193898    9806.732716  0.002662
# 1                 0.8        0.810526    0.196449    9846.047501  0.002660
# 2                 0.8        0.821053    0.199000    9885.419259  0.002657
# 3                 0.8        0.831579    0.201552    9924.849127  0.002654
# 4                 0.8        0.842105    0.204103    9964.338177  0.002651
# ...               ...             ...         ...            ...       ...
# 2795              0.1        1.157895    1.262887   39771.876388  0.004086
# 2796              0.1        1.168421    1.274368   39989.582852  0.004080
# 2797              0.1        1.178947    1.285849   40207.531167  0.004073
# 2798              0.1        1.189474    1.297330   40425.721366  0.004067
# 2799              0.1        1.200000    1.308811   40644.153425  0.004060
#
#           C2H6      C3H8     C4H10       CH4        CO       CO2        H2  \
# 0     0.012120  0.002651  0.001515  0.369276  0.073971  0.032251  0.208494
# 1     0.012107  0.002648  0.001513  0.368883  0.073684  0.032432  0.208507
# 2     0.012094  0.002646  0.001512  0.368491  0.073398  0.032612  0.208519
# 3     0.012082  0.002643  0.001510  0.368100  0.073114  0.032791  0.208529
# 4     0.012069  0.002640  0.001509  0.367710  0.072832  0.032968  0.208537
# ...        ...       ...       ...       ...       ...       ...       ...
# 2795  0.000517  0.000113  0.000065  0.016104  0.103440  0.054146  0.330923
# 2796  0.000516  0.000113  0.000064  0.016073  0.103003  0.054335  0.330682
# 2797  0.000515  0.000113  0.000064  0.016043  0.102569  0.054521  0.330439
# 2798  0.000514  0.000112  0.000064  0.016013  0.102138  0.054706  0.330196
# 2799  0.000513  0.000112  0.000064  0.015984  0.101710  0.054889  0.329953
#
#            H2O        N2
# 0     0.070771  0.226288
# 1     0.071514  0.226050
# 2     0.072258  0.225813
# 3     0.073000  0.225577
# 4     0.073743  0.225341
# ...        ...       ...
# 2795  0.152351  0.338256
# 2796  0.153420  0.337714
# 2797  0.154487  0.337174
# 2798  0.155552  0.336636
# 2799  0.156616  0.336099
#
# [2800 rows x 14 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# separate the data into inputs and outputs
inputs = ['Bypass Fraction', 'NG Steam Ratio']
outputs = [ 'Steam Flow', 'Reformer Duty','AR', 'C2H6', 'C3H8', 'C4H10',
           'CH4', 'CO', 'CO2', 'H2', 'H2O', 'N2']
dfin = df[inputs]
dfout = df[outputs]

# %%
X_train, X_test, y_train, y_test = train_test_split(dfin, dfout, test_size=0.95, random_state=42)

# %%
regr = linear_model.LinearRegression()
m=regr.fit(X_train, y_train)

# %%
from IPython.display import display, HTML
y_pred=pd.DataFrame(m.predict(X_test))
df_df=pd.DataFrame(y_test)
cols=df_df.columns
y_pred.columns=cols
y_pred
m.score(X_train,y_train)
display(HTML(pd.DataFrame(m.coef_).to_html()))

# m.intercept_
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.212170</td>
#       <td>0.669097</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-37435.932018</td>
#       <td>12179.854382</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.002025</td>
#       <td>-0.000515</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.014577</td>
#       <td>-0.000501</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.003189</td>
#       <td>-0.000110</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.001822</td>
#       <td>-0.000063</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.443457</td>
#       <td>-0.015819</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.053438</td>
#       <td>-0.038693</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.019988</td>
#       <td>0.019222</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.161677</td>
#       <td>-0.013950</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.065685</td>
#       <td>0.093271</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.160231</td>
#       <td>-0.042843</td>
#     </tr>
#   </tbody>
# </table>

# %%
heat_map_data=pd.concat([y_pred,df_df]).corr()
heat_map_data
# Out:
#                Steam Flow  Reformer Duty        AR      C2H6      C3H8  \
# Steam Flow       1.000000       0.992204  0.881405 -0.938739 -0.938739
# Reformer Duty    0.992204       1.000000  0.924622 -0.963338 -0.963338
# AR               0.881405       0.924622  1.000000 -0.987259 -0.987259
# C2H6            -0.938739      -0.963338 -0.987259  1.000000  1.000000
# C3H8            -0.938739      -0.963338 -0.987259  1.000000  1.000000
# C4H10           -0.938739      -0.963338 -0.987259  1.000000  1.000000
# CH4             -0.938945      -0.963458 -0.987143  1.000000  1.000000
# CO               0.752169       0.821380  0.970740 -0.920167 -0.920167
# CO2              0.965618       0.933418  0.806775 -0.890495 -0.890495
# H2               0.917454       0.949993  0.995717 -0.997738 -0.997738
# H2O              0.919923       0.867515  0.689724 -0.796150 -0.796150
# N2               0.878297       0.922326  0.999974 -0.986094 -0.986094
#
#                   C4H10       CH4        CO       CO2        H2       H2O  \
# Steam Flow    -0.938739 -0.938945  0.752169  0.965618  0.917454  0.919923
# Reformer Duty -0.963338 -0.963458  0.821380  0.933418  0.949993  0.867515
# AR            -0.987259 -0.987143  0.970740  0.806775  0.995717  0.689724
# C2H6           1.000000  1.000000 -0.920167 -0.890495 -0.997738 -0.796150
# C3H8           1.000000  1.000000 -0.920167 -0.890495 -0.997738 -0.796150
# C4H10          1.000000  1.000000 -0.920167 -0.890495 -0.997738 -0.796150
# CH4            1.000000  1.000000 -0.919883 -0.890825 -0.997690 -0.796588
# CO            -0.920167 -0.919883  1.000000  0.641283  0.944381  0.495716
# CO2           -0.890495 -0.890825  0.641283  1.000000  0.857946  0.984139
# H2            -0.997738 -0.997690  0.944381  0.857946  1.000000  0.753689
# H2O           -0.796150 -0.796588  0.495716  0.984139  0.753689  1.000000
# N2            -0.986094 -0.985974  0.972434  0.802524  0.995030  0.684522
#
#                      N2
# Steam Flow     0.878297
# Reformer Duty  0.922326
# AR             0.999974
# C2H6          -0.986094
# C3H8          -0.986094
# C4H10         -0.986094
# CH4           -0.985974
# CO             0.972434
# CO2            0.802524
# H2             0.995030
# H2O            0.684522
# N2             1.000000

# %%
import plotly.express as px
fig=px.imshow(heat_map_data)
fig.show()

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(df_df, y_pred)
# Out:
# 0.9432477057526222
